# %% [markdown]
# EN 302 Assignment 2
#
# Q1.
#
# a. average plant load factor
#
# b. Unit Capacity
#
# c. Power generation efficiency
#
# d. Annual generation in kWhr

# %% [markdown]
# __[Link for the Ultimate Analysis](https://forestsclearance.nic.in/writereaddata/FormA/Miningletter/811171249121990Q47EPR_15_MTY.pdf)__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Average_plant_load_factor = 91.4        ## %  
Unit_capacity = 210                     ## MW
Annual_generation = 1681.39             ## MWhr

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
# ![image.png](attachment:image.png)
#
#
# ![image-6.png](attachment:image-6.png)
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-7.png](attachment:image-7.png)
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-8.png](attachment:image-8.png)
# ![image-4.png](attachment:image-4.png)
#
#
# ![image-10.png](attachment:image-10.png)
# ![image-9.png](attachment:image-9.png)
#
#
# The following is the data from the Thermal Review of the
# Vindhychal STPS plant

# %% [markdown]
# Q2.
#
# a. Calorific value of coal used
#
# b. Ultimate analysis of the coal used
#
# c. According to power generated how much coal will be used
#
# d. Amounts of CO2 and SO2 emitted annually

# %%
Calorific_value_of_coal = (4310 + 5970)/2   ## kcal/kg
Specific_coal_consumption = 0.653           ## kg/kWhr

class CoalComposition:
    def __init__(self, C: float, H: float, N: float, O: float,S: float) -> None:
        """Generated a class which stores percentages of each 

        Args:
            C (float): _description_
            H (float): _description_
            N (float): _description_
            O (float): _description_
            S (float): _description_
        """
        self.C = C
        self.H = H
        self.N = N
        self.S = S
        self.O = O

# %% [markdown]
# Q3.
# excess air ratio = 1.1
# a. Volume of flue gas generated in Nm3/h
# b. % CO2 and %SO2 in the flue gas in mol%
#
# (assume a humidity for air combustion & consider annual average to calculate it.)

# %% [markdown]
# Q4.
#
# a. Select a suitable solvent to capture CO2 in this power plant
# b. solubility of CO2 and the regeneration energy requirement in MJ/t of CO2 for chosen solvent?
# specific pressure and temperature
# c. find solvent flow rate to capture 90% CO2
# d. Calculate regeneration energy required

# %% [markdown]
# Q5.
#
# a. Assume that the regeneration energy is met through saturated LP steam (5 bar). Find the
# amount of steam needed.
# b. If this steam is generated in a biomass-fired boiler with an efficiency of 90%, find the amount of biomass required.
# c. Consider a biomass that is available in the vicinity of the plant and mention its calorific value. Is this a viable proposition with regards to the availability, transport and storage of biomass?

# %% [markdown]
# Q6.
#
# a. Corresponding to the amount of coal and biomass used, find the storage yard requirement (in m2).
# b. Assume a density for coal and biomass, and assume that the heap cannot have a height of more than 10 m. How do they compare?

# %% [markdown]
# Q7.
# a. What is the amount of limestone required to capture 95% of the SO2 in the flue gas? What is the storage yard area (in m2) needed for this? What is the amount of gypsum formed?

# %% [markdown]
# Q8.
#
# a. If the regeneration energy in the CO2 unit is met by the LP steam from the power plant, what will be the power output? What is the plant efficiency under this condition?
